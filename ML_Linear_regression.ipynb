# %% [markdown]
# <a href="https://colab.research.google.com/github/bijivemulasumanthkumarreddy/MACHINE-LEARNING-/blob/main/ML_Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#initally we need to import the required librariessuch as numpy,pandas and matplotlib for ploting graphs
#next classify the data set for indepenedent and dependent varibles and store in specific varibles
#split the data as train set and test set
#create a linear regression b/w train data sets
#make the predictions b/w test and train data sets
#make scatter plot with train predictions
#plot the line which shows the relation b/w train and test data  perdictons
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x= df.iloc[:,:-1].values
y= df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 2/3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= regressor.predict(x_test)
x_pred= regressor.predict(x_train)

# %%
plt.scatter(x_train,y_train,color="black")
plt.plot(x_train,x_pred,color="green")
plt.title("salary prediction")
plt.xlabel("Years(Experience)")
plt.ylabel("Salary(In Rupees)")
plt.show()
